# %%
import yfinance as yf

# %%
'''@utils.log_indent_decorator def download(tickers: Any,
             start: Any = None,
             end: Any = None,
             actions: bool = False,
             threads: bool = True,
             ignore_tz: Any = None,
             group_by: str = 'column',
             auto_adjust: Any = None,
             back_adjust: bool = False,
             repair: bool = False,
             keepna: bool = False,
             progress: bool = True,
             period: str = "max",
             interval: str = "1d",
             prepost: bool = False,
             proxy: object = _SENTINEL_,
             rounding: bool = False,
             timeout: int = 10,
             session: Any = None,
             multi_level_index: bool = True) -> DataFrame | None'''
data = yf.download("1288.HK", start="2025-03-01", end="2025-04-09", back_adjust=True, multi_level_index=False, rounding=True, actions=True)
data
# Out:
# [*********************100%***********************]  1 of 1 completed
#             Close  Dividends  High   Low  Open  Stock Splits     Volume
# Date
# 2025-03-03   4.70        0.0  4.73  4.61  4.64           0.0  182894892
# 2025-03-04   4.67        0.0  4.72  4.63  4.69           0.0  140125186
# 2025-03-05   4.75        0.0  4.82  4.67  4.70           0.0  120064297
# 2025-03-06   4.75        0.0  4.79  4.71  4.76           0.0  128358560
# 2025-03-07   4.73        0.0  4.77  4.72  4.73           0.0  110037619
# 2025-03-10   4.72        0.0  4.75  4.66  4.73           0.0   97318735
# 2025-03-11   4.77        0.0  4.80  4.68  4.70           0.0  135782261
# 2025-03-12   4.88        0.0  4.88  4.74  4.74           0.0  180403350
# 2025-03-13   4.90        0.0  4.98  4.85  4.88           0.0  204863573
# 2025-03-14   4.96        0.0  5.05  4.91  4.91           0.0  217885082
# 2025-03-17   5.02        0.0  5.02  4.96  5.00           0.0  113518883
# ...
